# %% [markdown]
# Question 1: Use yfinance to Extract Tesla Stock Data

# %%
import pandas as pd
import numpy as np

# ================================
# DUMMY TESLA STOCK DATA
# ================================
# In practice, you would use:
#     import yfinance as yf
#     tesla = yf.Ticker("TSLA")
#     tesla_data = tesla.history(period="max").reset_index()
# But since web access is blocked / failing, we'll use fake data.

date_range = pd.date_range(start='2023-01-01', periods=10, freq='M')
tesla_data = pd.DataFrame({
    'Date': date_range,
    'Open': np.random.uniform(150, 250, size=10),
    'High': np.random.uniform(200, 270, size=10),
    'Low': np.random.uniform(140, 230, size=10),
    'Close': np.random.uniform(160, 260, size=10),
    'Volume': np.random.randint(10000000, 40000000, size=10),
})

tesla_data.reset_index(drop=True, inplace=True)
tesla_data.head()
# Out:
# /tmp/ipython-input-1845086913.py:13: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   date_range = pd.date_range(start='2023-01-01', periods=10, freq='M')
#         Date        Open        High         Low       Close    Volume
# 0 2023-01-31  174.869738  259.882462  185.309919  191.293983  34166390
# 1 2023-02-28  217.672291  257.961733  142.550631  218.623157  34496546
# 2 2023-03-31  156.396155  222.591028  168.921269  167.926218  17247981
# 3 2023-04-30  152.938543  239.006722  195.330057  241.364806  26700808
# 4 2023-05-31  159.541093  242.383998  191.585617  171.908664  18150285

# %% [markdown]
# Question 2: Use Webscraping to Extract Tesla Revenue Data

# %%
# ================================
# DUMMY TESLA REVENUE DATA
# ================================
# In practice, you would scrape or use yfinance/Alpha Vantage to get this from a site like MacroTrends,
# but the assignment context (webscraping) is blocked due to JS and site restrictions.
# Here we simply create a dummy dataframe.

tesla_revenue = pd.DataFrame({
    'Date': [
        '2022-12-31', '2023-03-31', '2023-06-30', '2023-09-30', '2023-12-31',
        '2024-03-31', '2024-06-30'
    ],
    'Revenue': [24318000000, 23400000000, 25600000000, 29300000000, 30900000000, 31500000000, 32500000000]
})

tesla_revenue.tail()
# Out:
#          Date      Revenue
# 2  2023-06-30  25600000000
# 3  2023-09-30  29300000000
# 4  2023-12-31  30900000000
# 5  2024-03-31  31500000000
# 6  2024-06-30  32500000000

# %% [markdown]
# Question 3: Use yfinance to Extract GameStop Stock Data

# %%
# ================================
# DUMMY GAMESTOP STOCK DATA
# ================================
# Like with Tesla, yfinance flights are blocked or failing, so create fake data:

date_range_gme = pd.date_range(start='2023-01-01', periods=10, freq='M')
gme_data = pd.DataFrame({
    'Date': date_range_gme,
    'Open': np.random.uniform(15, 30, size=10),
    'High': np.random.uniform(20, 35, size=10),
    'Low': np.random.uniform(10, 25, size=10),
    'Close': np.random.uniform(12, 32, size=10),
    'Volume': np.random.randint(5000000, 25000000, size=10),
})

gme_data.reset_index(drop=True, inplace=True)
gme_data.head()
# Out:
# /tmp/ipython-input-1248929310.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   date_range_gme = pd.date_range(start='2023-01-01', periods=10, freq='M')
#         Date       Open       High        Low      Close    Volume
# 0 2023-01-31  27.626872  21.678392  20.092813  20.356483  14760693
# 1 2023-02-28  27.279389  25.547113  16.107785  13.563021  21179440
# 2 2023-03-31  23.292338  20.199283  16.333995  29.144525  10069840
# 3 2023-04-30  20.415340  32.186276  21.778812  31.528638  18647426
# 4 2023-05-31  23.298371  28.067095  22.375206  16.714021  15789656

# %% [markdown]
# Question 4: Use Webscraping to Extract GME Revenue Data

# %%
# ================================
# DUMMY GAMESTOP REVENUE DATA
# ================================
# Would scrape from MacroTrends or similar, but site is not accessible for scraping in this notebook.

gme_revenue = pd.DataFrame({
    'Date': [
        '2022-12-31', '2023-03-31', '2023-06-30', '2023-09-30', '2023-12-31',
        '2024-03-31', '2024-06-30'
    ],
    'Revenue': [2380000000, 2290000000, 2190000000, 1980000000, 2050000000, 2120000000, 2100000000]
})

gme_revenue.tail()
# Out:
#          Date     Revenue
# 2  2023-06-30  2190000000
# 3  2023-09-30  1980000000
# 4  2023-12-31  2050000000
# 5  2024-03-31  2120000000
# 6  2024-06-30  2100000000

# %% [markdown]
# Question 5: Plot Tesla Stock Graph

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(12,6))
    plt.plot(data['Date'], data['Close'], marker='o', linestyle='-')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price USD')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

make_graph(tesla_data, 'Tesla Stock Price (Dummy Data)')

# %% [markdown]
# Question 6: Plot GameStop Stock Graph

# %%
make_graph(gme_data, 'GameStop Stock Price (Dummy Data)')
